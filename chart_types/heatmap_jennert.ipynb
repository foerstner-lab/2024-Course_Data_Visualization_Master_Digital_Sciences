# %% [markdown]
# # Heatmap
#
# **source_dataset: https://www.kaggle.com/datasets/sudalairajkumar/daily-temperature-of-major-cities?resource=download**

# %%
# !pip install pandas seaborn matplotlib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv('data/city_temperature.csv')
# Filter out years smaller than 1900
data = data[data['Year'] >= 1900]
data
# Out:
# /var/folders/zq/jp8w61g90hjb23085zxdk5lw0000gn/T/ipykernel_60171/2774419961.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/city_temperature.csv')
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# ...

# %%
# Group by Region and calculate the average temperature
average_temperatures_by_region_year = data.groupby(['Region','Year'])['AvgTemperature'].mean().reset_index()

# Rename the columns
average_temperatures_by_region_year.columns = ['Region', 'Year', 'AvgTemperature']

print(average_temperatures_by_region_year)
# Out:
#                                 Region  Year  AvgTemperature
# 0                               Africa  1995       52.976737
# 1                               Africa  1996       48.348380
# 2                               Africa  1997       37.282495
# 3                               Africa  1998       30.327075
# 4                               Africa  1999       34.153869
# ..                                 ...   ...             ...
# 177  South/Central America & Carribean  2016       70.048035
# 178  South/Central America & Carribean  2017       69.952968
# 179  South/Central America & Carribean  2018       69.446720
# 180  South/Central America & Carribean  2019       69.635753
# 181  South/Central America & Carribean  2020       72.515579
#
# [182 rows x 3 columns]

# %%
# Create a pivot table
heatmap_data = average_temperatures_by_region_year.pivot_table(index='Region', columns='Year', values='AvgTemperature')

# Create the heatmap
plt.figure(figsize=(20, 12))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=True, fmt=".1f", linewidths=.5)
plt.title('Average Temperature by Region and Year')
plt.xlabel('Year')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# # Alternative names (based on context and use case)

# %% [markdown]
# ## Density Map
# [![ Alt Text](https://www.researchgate.net/publication/348661753/figure/fig2/AS:1022659894734850@1620832527404/Relative-kernel-density-map-showing-concentrations-of-grave-good-use-across-Western.ppm)]()

# %% [markdown]
# ## Intensity Map
#
# [![ Alt Text](https://www.researchgate.net/publication/343794082/figure/fig2/AS:926969877237760@1598018249623/Rainfall-intensity-map.png)]()

# %% [markdown]
# ## Choropleth Map
#
# [![ Alt Text](https://upload.wikimedia.org/wikipedia/commons/thumb/e/e9/Choropleth_Map.png/300px-Choropleth_Map.png)]()

# %% [markdown]
# ## Hotspot Map
#
# [![ Alt Text](https://enterprise.arcgis.com/de/portal/10.4/use/GUID-EE6F4EA7-683D-4C9B-947B-8DF4CA30D87C-web.png)]()

# %% [markdown]
# # Aesthetics used
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Potential Pitfalls
#
# - Illusion with colors: https://www.displayr.com/the-problem-with-heatmaps/
# - Color choice could lead to misinterpretation

# %% [markdown]
# # MQC
#
# Which statement best describes a heatmap?
#
# - A) It displays data on a geographical map.
# - B) It represents hierarchical data in a tree-like structure.
# - C) It visualizes data values using colors.
# - D) It analyzes correlations between continuous variables.
